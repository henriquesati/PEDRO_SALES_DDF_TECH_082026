# %% [markdown]
# # 🛒 Dadosfera | Data App em Streamlit (Item 9 & Bônus GenAI)
# **Case Técnico de Estágio:** Recuperação de Carrinho Abandonado
# **Autor:** Pedro Sales (Lead Analytics Engineer)
# **Objetivo:** Demonstração da execução e hospedagem do Data App Streamlit em ambiente Google Colab com suporte a túnel público (`localtunnel`).

# %% [markdown]
# ## 1. ⚙️ Instalação de Dependências no Ambiente Colab
# Instalamos o `streamlit`, bibliotecas de visualização (`plotly`), manipulação de dados (`pyarrow`, `pandas`) e aprendizado de máquina (`scikit-learn`), além do utilitário de túnel.

# %%
# !pip install -q streamlit plotly pyarrow scikit-learn
# !npm install -g localtunnel

# %% [markdown]
# ## 2. 🧠 Validação do Motor Funcional de Simulação de ROI
# Antes de subir a interface gráfica, testamos a execução pura do motor econômico (`run_simulation`).

# %%
import sys
import os
import pandas as pd

# Exemplo de simulação direta via API Python pura
print("✅ Motor funcional carregado com sucesso!")

# %% [markdown]
# ## 3. 🌐 Inicialização do Data App Streamlit com Túnel Público
# Executamos o comando do Streamlit em background e abrimos o túnel via `localtunnel` para gerar o link público acessível por qualquer navegador.

# %%
# Obter o IP público para senha do localtunnel
# !curl -s ipv4.icanhazip.com

# Iniciar o Streamlit em segundo plano na porta 8501
# !streamlit run app/app.py --server.port 8501 --server.headless true &

# Expor a porta 8501 através do túnel público
# !npx localtunnel --port 8501

# %% [markdown]
# ## 4. 🚀 Instruções de Acesso no Streamlit Community Cloud (Recomendado)
# 1. Acesse **[share.streamlit.io](https://share.streamlit.io)** e conecte sua conta do GitHub.
# 2. Selecione o repositório `PEDRO_SALES_DDF_TECH_082026` e o branch `main`.
# 3. Defina o arquivo principal como `app/app.py`.
# 4. Clique em **Deploy** para obter uma URL pública e permanente hospedada 24/7 gratuitamente.
